// %% [markdown]
// #Excercises 14.09
// ##Conceptual Questions

// %% [markdown]
// Q1. What is the difference between let, const JavaScript?

// %%
let a = 10;
a
// Out:
// 10

// %%
let b = 20;
a+b
// Out:
// 30

// %%
[1, 2, 3, 4].map(x => x * 2)
// Out:
// [ 2, 4, 6, 8 ]

// %%
let name = "Nico";
console.log(name);
// Out:
// Nico
